# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
# %pylab inline
from matplotlib import pyplot as plt
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
training_data=pd.read_csv('data/aug_train.txt')
training_data
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
training_data.describe()
# Out:
#         enrollee_id  city_development_index  training_hours        target
# count  19158.000000            19158.000000    19158.000000  19158.000000
# mean   16875.358179                0.828848       65.366896      0.249348
# std     9616.292592                0.123362       60.058462      0.432647
# min        1.000000                0.448000        1.000000      0.000000
# 25%     8554.250000                0.740000       23.000000      0.000000
# 50%    16982.500000                0.903000       47.000000      0.000000
# 75%    25169.750000                0.920000       88.000000      0.000000
# max    33380.000000                0.949000      336.000000      1.000000

# %%
training_data.plot.hist(column=['training_hours'],by="education_level",figsize=(10,17))
# Out:
# array([<AxesSubplot:title={'center':'Graduate'}, ylabel='Frequency'>,
#        <AxesSubplot:title={'center':'High School'}, ylabel='Frequency'>,
#        <AxesSubplot:title={'center':'Masters'}, ylabel='Frequency'>,
#        <AxesSubplot:title={'center':'Phd'}, ylabel='Frequency'>,
#        <AxesSubplot:title={'center':'Primary School'}, ylabel='Frequency'>],
#       dtype=object)

# %%
training_data.boxplot(column=['training_hours','city_development_index'])
# Out:
# <AxesSubplot:>

# %%
training_data.experience.unique()
# Out:
# array(['>20', '15', '5', '<1', '11', '13', '7', '17', '2', '16', '1', '4',
#        '10', '14', '18', '19', '12', '3', '6', '9', '8', '20', nan],
#       dtype=object)

# %% [markdown]
# <h1>TO DO</h1>
# <h2>Cleaning:</h2>
# 1) Convert to categorical variables for experience, company_size, company_type, education_level, enrolled_university
# 2) Clean NaN's
#
#
# <h2>Plots:</h2>
# 1) box plots for above to see outliers? Histograms of columns, which ones?
#
#
# <h3>Transformations for extra work:</h3>
# 1) Rename cities and plot on maps

# %%
training_data['experience'].replace('<1',0,inplace=True)
training_data['experience'].replace('>20',21,inplace=True)
