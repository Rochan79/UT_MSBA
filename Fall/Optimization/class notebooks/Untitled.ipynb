# %%
pip install quora-scraper
# Out:
# Collecting quora-scraper
#   Downloading quora_scraper-1.1.3-py3-none-any.whl (5.2 MB)
# Requirement already satisfied: selenium in c:\users\rochan nehete\anaconda3\lib\site-packages (from quora-scraper) (4.4.3)
# Collecting webdriver-manager
#   Downloading webdriver_manager-3.8.3-py2.py3-none-any.whl (26 kB)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting dateparser
#   Downloading dateparser-1.1.1-py2.py3-none-any.whl (288 kB)
# Collecting userpaths
#   Downloading userpaths-0.1.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\rochan nehete\anaconda3\lib\site-packages (from bs4->quora-scraper) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rochan nehete\anaconda3\lib\site-packages (from beautifulsoup4->bs4->quora-scraper) (2.3.1)
# Collecting regex!=2019.02.19,!=2021.8.27,<2022.3.15
#   Downloading regex-2022.3.2-cp39-cp39-win_amd64.whl (274 kB)
# Requirement already satisfied: pytz in c:\users\rochan nehete\anaconda3\lib\site-packages (from dateparser->quora-scraper) (2021.3)
# Collecting tzlocal
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: python-dateutil in c:\users\rochan nehete\anaconda3\lib\site-packages (from dateparser->quora-scraper) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\rochan nehete\anaconda3\lib\site-packages (from python-dateutil->dateparser->quora-scraper) (1.16.0)
# Requirement already satisfied: trio~=0.17 in c:\users\rochan nehete\anaconda3\lib\site-packages (from selenium->quora-scraper) (0.21.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\rochan nehete\anaconda3\lib\site-packages (from selenium->quora-scraper) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\rochan nehete\anaconda3\lib\site-packages (from selenium->quora-scraper) (2021.10.8)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\rochan nehete\anaconda3\lib\site-packages (from selenium->quora-scraper) (1.26.9)
# Requirement already satisfied: idna in c:\users\rochan nehete\anaconda3\lib\site-packages (from trio~=0.17->selenium->quora-scraper) (3.3)
# Requirement already satisfied: sniffio in c:\users\rochan nehete\anaconda3\lib\site-packages (from trio~=0.17->selenium->quora-scraper) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\rochan nehete\anaconda3\lib\site-packages (from trio~=0.17->selenium->quora-scraper) (1.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\rochan nehete\anaconda3\lib\site-packages (from trio~=0.17->selenium->quora-scraper) (1.15.0)
# Requirement already satisfied: outcome in c:\users\rochan nehete\anaconda3\lib\site-packages (from trio~=0.17->selenium->quora-scraper) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\rochan nehete\anaconda3\lib\site-packages (from trio~=0.17->selenium->quora-scraper) (21.4.0)
# Requirement already satisfied: sortedcontainers in c:\users\rochan nehete\anaconda3\lib\site-packages (from trio~=0.17->selenium->quora-scraper) (2.4.0)
# Requirement already satisfied: pycparser in c:\users\rochan nehete\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium->quora-scraper) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\rochan nehete\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium->quora-scraper) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\rochan nehete\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium->quora-scraper) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\rochan nehete\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->quora-scraper) (0.13.0)
# Collecting tzdata
#   Downloading tzdata-2022.4-py2.py3-none-any.whl (336 kB)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-0.21.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: tqdm in c:\users\rochan nehete\anaconda3\lib\site-packages (from webdriver-manager->quora-scraper) (4.64.0)
# Requirement already satisfied: requests in c:\users\rochan nehete\anaconda3\lib\site-packages (from webdriver-manager->quora-scraper) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\rochan nehete\anaconda3\lib\site-packages (from requests->webdriver-manager->quora-scraper) (2.0.4)
# Requirement already satisfied: colorama in c:\users\rochan nehete\anaconda3\lib\site-packages (from tqdm->webdriver-manager->quora-scraper) (0.4.4)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=1a6ea2a727d93a0b2984238c5f594d11650dd1a24f1e31466eb25621925a9389
#   Stored in directory: c:\users\rochan nehete\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# Installing collected packages: tzdata, pytz-deprecation-shim, tzlocal, regex, python-dotenv, webdriver-manager, userpaths, dateparser, bs4, quora-scraper
#   Attempting uninstall: regex
#     Found existing installation: regex 2022.3.15
#     Uninstalling regex-2022.3.15:
#       Successfully uninstalled regex-2022.3.15
# Successfully installed bs4-0.0.1 dateparser-1.1.1 python-dotenv-0.21.0 pytz-deprecation-shim-0.1.0.post0 quora-scraper-1.1.3 regex-2022.3.2 tzdata-2022.4 tzlocal-4.2 userpaths-0.1.3 webdriver-manager-3.8.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import datetime
from selenium.webdriver.chrome.options import Options
import os
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import csv

# start time
start_time = datetime.datetime.now()

# read topics form a file
file_question_topics = open("topic_list.txt", mode='r', encoding='utf-8')
topics = file_question_topics.readlines()

for topic in topics:
	# read questions form files under questions directory
	questions_file = topic + '_question_urls.txt'
	questions = open('questions/'+ questions_file, mode='r', encoding='utf-8')

	for question in questions:
		print('Question: ' + question)
		# instantiate a chrome options object so you can set the size and headless preference
		chrome_options = Options()
		chrome_options.add_argument("--headless")
		chrome_options.add_argument(" --window-size=1920x1080")

		# download the chrome driver from https://sites.google.com/a/chromium.org/chromedriver/downloads
		# and put it in the current directory
		chrome_driver = os.getcwd() + "/chromedriver"

		# Set the browser settings to web driver
		driver = webdriver.Chrome(chrome_options=chrome_options, executable_path=chrome_driver)
		# driver = webdriver.Chrome(executable_path=chrome_driver)

		# give the url to scrap
		driver.get(question)

		# define pause time for browser
		SCROLL_PAUSE_TIME = 3

		# get browser source
		html_source = driver.page_source
		question_count_soup = BeautifulSoup(html_source, 'html.parser')

		# Get scroll height
		last_height = driver.execute_script("return document.body.scrollHeight")
		answer_set = set()

		# infinite while loop, break it when you reach the end of the page or not able to scroll further.
		while True:
			html_source = " "
			i = 0

			# try to scroll 20 times in case of slow connection
			while i < 20:

				# Scroll down to one page length
				driver.execute_script("window.scrollBy(0, 1080);")

				# Wait to load page
				time.sleep(SCROLL_PAUSE_TIME)

				# get page height in pixels
				new_height = driver.execute_script("return document.body.scrollHeight")

				# break this loop when you are able to scroll futher
				if new_height != last_height:
					break
				i += 1

			# get html page source
			html_source = driver.page_source
			soup = BeautifulSoup(html_source, 'html.parser')

			# question_link is the class for questions
			answer_texts = soup.find_all('div', attrs={'class': 'ui_qtext_expanded'})

			# add questions to a set for uniqueness
			for answer in answer_texts:
				# <div class=""ui_qtext_expanded""><span class=""ui_qtext_rendered_qtext"">
				answer = str(answer).lstrip("<div class=\"ui_qtext_expanded\"><span class=\"ui_qtext_rendered_qtext\">").rstrip("</span></div>")
				answer_set.add(answer)

			# not able to scroll further, break the infinite loop
			new_height = driver.execute_script("return document.body.scrollHeight")
			if new_height == last_height:
				break
			last_height = new_height

			print('Total Answers: ' + str(len(answer_set)))

		#write contents of set to a file called answers.txt
		answers_directory = 'answers'
		os.makedirs('answers', exist_ok=True)
		file_name = answers_directory + '/' + topic + '_answers.txt'
		file_answers = open(file_name, mode='a', encoding='utf-8')
		writer = csv.writer(file_answers)
		for answer in answer_set:
			# link_url = "http://www.quora.com" + ques.attrs['href']
			print(answer)
			writer.writerows([[answer]])

		print('quitting chrome')
		driver.quit()

# finish time
end_time = datetime.datetime.now()
print(end_time-start_time)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [11], in <cell line: 16>()
#      16 for topic in topics:
#      17 	# read questions form files under questions directory
#      18 	questions_file = topic + '_question_urls.txt'
# ---> 19 	questions = open('questions/'+ questions_file, mode='r', encoding='utf-8')
#      21 	for question in questions:
#      22 		print('Question: ' + question)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'questions/finance_question_urls.txt'

# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("https://www.nytimes.com")
headlines = driver.find_element("story-heading")
for headline in headlines:
    print(headline.text.strip())
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Input In [12], in <cell line: 4>()
#       2 driver = webdriver.Chrome()
#       3 driver.get("https://www.nytimes.com")
# ----> 4 headlines = driver.find_element("story-heading")
#       5 for headline in headlines:
#       6     print(headline.text.strip())
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:855, in WebDriver.find_element(self, by, value)
#     852     by = By.CSS_SELECTOR
#     853     value = '[name="%s"]' % value
# --> 855 return self.execute(Command.FIND_ELEMENT, {
#     856     'using': by,
#     857     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# InvalidArgumentException: Message: invalid argument: invalid locator
#   (Session info: chrome=105.0.5195.127)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0025DF13+2219795]
# 	Ordinal0 [0x001F2841+1779777]
# 	Ordinal0 [0x0010423D+803389]
# 	Ordinal0 [0x00132AC9+993993]
# 	Ordinal0 [0x001331EB+995819]
# 	Ordinal0 [0x00160F52+1183570]
# 	Ordinal0 [0x0014E844+1108036]
# 	Ordinal0 [0x0015F192+1175954]
# 	Ordinal0 [0x0014E616+1107478]
# 	Ordinal0 [0x00127F89+950153]
# 	Ordinal0 [0x00128F56+954198]
# 	GetHandleVerifier [0x00552CB2+3040210]
# 	GetHandleVerifier [0x00542BB4+2974420]
# 	GetHandleVerifier [0x002F6A0A+565546]
# 	GetHandleVerifier [0x002F5680+560544]
# 	Ordinal0 [0x001F9A5C+1808988]
# 	Ordinal0 [0x001FE3A8+1827752]
# 	Ordinal0 [0x001FE495+1827989]
# 	Ordinal0 [0x002080A4+1867940]
# 	BaseThreadInitThunk [0x76D16739+25]
# 	RtlGetFullPathName_UEx [0x77C78FD2+1218]
# 	RtlGetFullPathName_UEx [0x77C78F9D+1165]
# 	(No symbol) [0x00000000]
